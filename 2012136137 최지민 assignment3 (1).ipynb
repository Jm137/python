# %% [markdown]
# 1) L=[1, 2, 3, 4, 5]일 때 다음 각 문장을 수행한 후의 결과를 보고 납득할 만한 이유를 설명하시오.

# %%
#1-1
L=[1, 2, 3, 4, 5]
L[1:3] = [100]
print L
# Out:
# [1, 100, 4, 5]

# %% [markdown]
# 슬라이싱을 이용해 2번째 원소부터 네번째 원소앞까지를 100으로 치환하는데, 리스트에 리스트를 슬라이싱하여 추가함을 보여줌. 하나의 원소로 치환하여 총 원소 갯수는 4개가 된다

# %%
#1-2
L=[1, 2, 3, 4, 5]
L[1:3] = [(100)]
print L
# Out:
# [1, 100, 4, 5]

# %% [markdown]
# 슬라이싱으로 두번째~네번째 앞까지를 (100)으로 치환. 튜플을 원소로하는 리스트도 슬라이싱을 이용하여 리스트에 추가됨. 두자리를 하나의 원소로 치환하여 총 원소는 4개이다.

# %%
#1-3
L=[1, 2, 3, 4, 5]
L[1:3] = 100
print L
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-e6aeeb67e41e> in <module>()
#       1 #1-3
#       2 L=[1, 2, 3, 4, 5]
# ----> 3 L[1:3] = 100
#       4 print L
#
# TypeError: can only assign an iterable

# %% [markdown]
# 시퀀스 자료형이 요구되는데 수치자료형이기때문에 오류가 발생.

# %%
#1-4
L=[1, 2, 3, 4, 5]
L[1:3] = (100)
print L
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-6e777ae9fa4a> in <module>()
#       1 #1-4
#       2 L=[1, 2, 3, 4, 5]
# ----> 3 L[1:3] = (100)
#       4 print L
#
# TypeError: can only assign an iterable

# %% [markdown]
# 튜플의 자료가 하나일땐 (100,) 을 해주어야 튜플로 인식된다,

# %%
#1-5
L=[1, 2, 3, 4, 5]
L[1:3] = (100, 101, 102)
print L
# Out:
# [1, 100, 101, 102, 4, 5]

# %% [markdown]
# 슬라이스 치환을 이용하여 리스트의 인덱스 1번, 2번 원소인 2와 3을 우측의 튜플로 치환. 치환할 내용이 주어진 자리보다 크지만 다른 원소들은 삭제되지 않고 그대로 유지.

# %%
#1-6
L=[1, 2, 3, 4, 5]
L[1:3] = [100, 101, 102]
print L
# Out:
# [1, 100, 101, 102, 4, 5]

# %% [markdown]
# 슬라이스 치환을 이용하여 리스트의 원소들을 우측의 리스트로 바꿈. 지정한 자리보다 치환할 리스트의 크기가 커도 정상적으로 수행.

# %%
#1-7
L=[1, 2, 3, 4, 5]
L[1:3] = [(100, 101, 102)]
print L
# Out:
# [1, (100, 101, 102), 4, 5]

# %% [markdown]
# (100,101,102) 튜플하나가 리스트의 원소이다. 지정된 자리보다 작지만 수행은 정상적으로 수행.

# %%
#1-8
L=[1, 2, 3, 4, 5]
L[1:3] = [[100, 101, 102]]
print L
# Out:
# [1, [100, 101, 102], 4, 5]

# %% [markdown]
# 한 개의 리스트를 원소로 갖는 리스트로 차환. 지정된 자리보다 치환할 리스트의 크기가 작지만 정상적으로 치환.

# %% [markdown]
# 2)•문자열 S = 'Hello World and Python'에 대해 다음 요구사항에 대한 Python 코드를 제시하시오.
# ◾1) 단어의 순서가 역순으로 되어진 문자열 ('Python and World Hello')을 만들고
# ◾2) 1)의 결과 문자열에 대해 메소드 split과 join을 이용하여 공백을 모두 없엔 문자열 'PythonandWorldHello'을 만드시오.

# %%
#2
S = 'Hello World and Python'
#2-1
r = S.split() #문자열을 공백으로 분리
r = r[::-1] #역순으로 취함
r = ' '.join(r) #리스트를 문자열으로 결합
print r

#2-2
r = r.split() 
r = ''.join(r)
print r
# Out:
# Python and World Hello
# PythonandWorldHello

# %% [markdown]
# 문자열을 공백으로 분리하는 split()과 리스트를 문자열로 결합하는 join()을 사용.

# %% [markdown]
# 3)•다음 코드를 보고 물음에 답하시오.
# a = [1, 2, 3]
# b = a * 3
# c = [a] * 3
# print b
# print c
# ◾1) 위 코드를 수행한 이후 다음 코드를 수행한 후 b와 c의 내용을 확인하시오.
#     a[0]=0
# ◾2) b와 c 객체의 차이는 무엇인가?

# %%
#3-1
a = [1, 2, 3]
b = a * 3
c = [a] * 3
print b
print c
a[0] = 0
print b
print c
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# [[1, 2, 3], [1, 2, 3], [1, 2, 3]]
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# [[0, 2, 3], [0, 2, 3], [0, 2, 3]]

# %% [markdown]
# b는 그대로 c는 변화되었다.
# b에는 a의 값을 복사하여 리스트에 저장하였고, c에는 a의 객체레퍼런스를 복사하여 저장하였기 때문에, c의 값은 a값이 변할때 같이 변함.

# %% [markdown]
# 4)•다음 문자열을 ':'을 기준으로 분리하여 리스트로 만들고 각 문자열의 좌우 공백을 제거하시오 (즉, 문자열 S에서 l을 만들어라) s = '  first star   :   second star   :    third star  '
# l = ['first star', 'second star', 'third star']
#
# ◾1) for ~ in 문을 이용한 코드를 작성하시오.
# ◾2) 리스트 내포(list comprehension)를 이용한 코드를 작성하시오.

# %%
s = '  first star  :  second star  :  third star  '

L1 = []
L2 = []
#1
for k in s.split(':') :
    L1.append(k.strip())
print L1

#2
L2 = [k.strip() for k in s.split(':')]
print L2
# Out:
# ['first star', 'second star', 'third star']
# ['first star', 'second star', 'third star']

# %% [markdown]
# split, strip 함수를 이용하여 문자열을 분리하고 좌우 공백을 삭제.
# for문과 리스트 내포.

# %% [markdown]
# 5)•다음과 같이 0보다 큰 정수 리스트 변수 list를 인자로 받는 함수 addall(list)와 addallodd(list)를 for ~ in 리터널과 리스트 내포 방식으로 각각 제시하시오.
# ◾1) addall(list) 함수 (리스트 내의 모든 정수를 더하는 함수로서 해답으로는 for ~ in 리터럴과 리스트 내포 방식으로 각각 제시하시오.)
# ◦>>> addall([1])
# 1
# ◦>>> addall([1, 2, 3, 4, 5, 6, 7, 8, 9])
# 45
#
# ◾2) addallodd(list) 함수 (리스트내의 모든 홀수를 더하는 함수로서 해답으로는 for ~ in 리터럴과 리스트 내포 방식으로 각각 제시하시오.)◦>>> addallodd([1])
# 1
# ◦>>> addallodd([1, 2, 3, 4, 5, 6, 7, 8, 9])
# 25

# %%
def addall(list) :
    sum = 0
    for k in list :
        sum += k
    return sum

print addall([1, 2, 3, 4, 5, 6, 7, 8, 9])

def addall2(list) :
    L = [k for k in list]
    return sum(L)

print addall2([1, 2, 3, 4, 5, 6, 7, 8, 9])
# Out:
# 45
# 45

# %%
def addallodd(list) :
    sum = 0
    for k in list :
        if k % 2 :
            sum += k
    return sum

print addallodd([1, 2, 3, 4, 5, 6, 7, 8, 9])

def addallodd2(list) :
    L = [k for k in list if k % 2]
    return sum(L)
print addallodd2([1, 2, 3, 4, 5, 6, 7, 8, 9])
# Out:
# 25
# 25

# %% [markdown]
# for문과 리스트 내장방식을 각각이용.

# %% [markdown]
# 6)•다음 코드를 보고 물음에 답하시오.
# L1 = [1, 2, 3]
# L2 = [4, 5, 6]
# d = {'low':L1, 'high':L2}
# e = d
# f = d.copy()
# print d
# print e
# print f
# print
# d['low'] = [10, 20, 30]
# d['high'][1] = 500
# print d
# print e
# print f
#
# ◾1) 위 코드의 수행 결과 d와 e는 항상 같은 결과를 출력한다. 그 이유는 무엇인가?
# ◾2) 위 코드의 수행 결과 마지막 f의 내용은 다음과 같다. 이 때 'high' 키의 값 내용 중 500이 출력된 이유와 'low' 키의 값 내용 중 [1, 2, 3]이 출력된 이유를 설명하시오 ([hint]: shallow copy 관점에서 설명하시오.){'high': [4, 500, 6], 'low': [1, 2, 3]}

# %%
L1 = [1, 2, 3]
L2 = [4, 5, 6]
d = {'low':L1, 'high':L2}
e = d
f = d.copy()
print d
print e
print f
print
d['low'] = [10, 20, 30]
d['high'][1] = 500
print d
print e
print f
# Out:
# {'high': [4, 5, 6], 'low': [1, 2, 3]}
# {'high': [4, 5, 6], 'low': [1, 2, 3]}
# {'high': [4, 5, 6], 'low': [1, 2, 3]}
#
# {'high': [4, 500, 6], 'low': [10, 20, 30]}
# {'high': [4, 500, 6], 'low': [10, 20, 30]}
# {'high': [4, 500, 6], 'low': [1, 2, 3]}

# %% [markdown]
# 1)e는 d의 레퍼런스를 복사하여, d와 같은 객체를 참조하므로 항상 같은 값을 출력
# 2)f는 d를 얕은복사하여, 별도의 리스트 객체를 갖으면서 실제내용은 d와 같다.
# d['low'] = [10,20,30]에서 low가 참조하던 객체가 바뀌었는데, d와 f는 별도 객체로 이 변화의 반영은 없음.
# d['high'][1] = 500에서는 d객체의 high 키와 연관된 객체의 두번째 원소(인덱스1)의 값을 직접 바꾸는것으로, f가 참조하는 [4,5,6] 객체 내용을 직접 바꿔 f에도 변화가 반영됨.

# %% [markdown]
# 7)•사전 d = {'one':1, 'two':2, 'three':3, 'four':4, 'five':5}가 주어졌을 때 다음 요구사항에 맞는 코드를 제시하시오
# ◾[참고]: d.keys(), d.values()를 통해 리스트를 얻어낸 후 리스트가 지니고 있는 sort(cmp=None, key=None, reverse=False)함수를 활용하시오.
# ◾1) 키의 알파벳 오름차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.
# ◾2) 키의 알파벳 내림차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.
# ◾3) 값의 오름차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.
# ◾4) 값의 내림차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.

# %%
d = {'one':1, 'two':2, 'three':3, 'four':4, 'five':5}

#1
t = d.items()
t.sort()
print t

#2
t = d.items()
t.sort(reverse = True)
print t

#3
t = d.items()
def cmp1(a, b) :
    return cmp(a[1], b[1])
t.sort(cmp1)
print t

#4
t = d.items()
t.sort(cmp=cmp1, reverse=True)
print t
# Out:
# [('five', 5), ('four', 4), ('one', 1), ('three', 3), ('two', 2)]
# [('two', 2), ('three', 3), ('one', 1), ('four', 4), ('five', 5)]
# [('one', 1), ('two', 2), ('three', 3), ('four', 4), ('five', 5)]
# [('five', 5), ('four', 4), ('three', 3), ('two', 2), ('one', 1)]

# %% [markdown]
# .item()메소드로 사전 아이템을 튜플형태 리스트로 추출하고, 이후 리스트의 메소드를 사용하여 정렬수행

# %% [markdown]
# 8)[프로젝트 오일러 문제 7]

# %%
def prn(n):
    check = 0 
    if n % 2 == 0 : 
        if n == 2: return True
        else:    return False
    for i in range(3, n+1, 2):
        if n % i == 0:
            check += 1
    if check == 1:
        return True

pn = 2
L=[]
cnt = 0
while cnt < 10001:
    if prn(pn) == True:
        L.append(pn)
        cnt += 1
        pn += 1
    else:
        pn += 1
print L[-1]
# Out:
# 104743

# %% [markdown]
# 이전 과제의 소수 구하는 문제를 응용함. 2로 나뉘어지는 것은 2를 제외한 수, 즉 짝수 일 경우 False를 리턴해 제외시키고, 그 외의 수는 3부터 +2씩 하는 홀수로 나뉘어 소수인지 아닌지 검사받는다. 오직 자기자신으로만 나뉘어지므로 check=1 일때 True가 반환됨.
# cnt로 소수 카운트.

# %% [markdown]
# 9)[프로젝트 오일러 문제 8]

# %%
  num =('73167176531330624919225119674426574742355349194934'
'96983520312774506326239578318016984801869478851843'
'85861560789112949495459501737958331952853208805511'
'12540698747158523863050715693290963295227443043557'
'66896648950445244523161731856403098711121722383113'
'62229893423380308135336276614282806444486645238749'
'30358907296290491560440772390713810515859307960866'
'70172427121883998797908792274921901699720888093776'
'65727333001053367881220235421809751254540594752243'
'52584907711670556013604839586446706324415722155397'
'53697817977846174064955149290862569321978468622482'
'83972241375657056057490261407972968652414535100474'
'82166370484403199890008895243450658541227588666881'
'16427171479924442928230863465674813919123162824586'
'17866458359124566529476545682848912883142607690042'
'24219022671055626321111109370544217506941658960408'
'07198403850962455444362981230987879927244284909188'
'84580156166097919133875499200524063689912560717606'
'05886116467109405077541002256983155200055935729725'
'71636269561882670428252483600823257530420752963450')
L = []

for k in num:
    L.append(int(k))
    
print L

cp = 0
for i in range(len(L)-4):
    n = (L[i])*(L[i+1])*(L[i+2])*(L[i+3])*(L[i+4])
    if n > cp: cp = n
print cp
# Out:
# [7, 3, 1, 6, 7, 1, 7, 6, 5, 3, 1, 3, 3, 0, 6, 2, 4, 9, 1, 9, 2, 2, 5, 1, 1, 9, 6, 7, 4, 4, 2, 6, 5, 7, 4, 7, 4, 2, 3, 5, 5, 3, 4, 9, 1, 9, 4, 9, 3, 4, 9, 6, 9, 8, 3, 5, 2, 0, 3, 1, 2, 7, 7, 4, 5, 0, 6, 3, 2, 6, 2, 3, 9, 5, 7, 8, 3, 1, 8, 0, 1, 6, 9, 8, 4, 8, 0, 1, 8, 6, 9, 4, 7, 8, 8, 5, 1, 8, 4, 3, 8, 5, 8, 6, 1, 5, 6, 0, 7, 8, 9, 1, 1, 2, 9, 4, 9, 4, 9, 5, 4, 5, 9, 5, 0, 1, 7, 3, 7, 9, 5, 8, 3, 3, 1, 9, 5, 2, 8, 5, 3, 2, 0, 8, 8, 0, 5, 5, 1, 1, 1, 2, 5, 4, 0, 6, 9, 8, 7, 4, 7, 1, 5, 8, 5, 2, 3, 8, 6, 3, 0, 5, 0, 7, 1, 5, 6, 9, 3, 2, 9, 0, 9, 6, 3, 2, 9, 5, 2, 2, 7, 4, 4, 3, 0, 4, 3, 5, 5, 7, 6, 6, 8, 9, 6, 6, 4, 8, 9, 5, 0, 4, 4, 5, 2, 4, 4, 5, 2, 3, 1, 6, 1, 7, 3, 1, 8, 5, 6, 4, 0, 3, 0, 9, 8, 7, 1, 1, 1, 2, 1, 7, 2, 2, 3, 8, 3, 1, 1, 3, 6, 2, 2, 2, 9, 8, 9, 3, 4, 2, 3, 3, 8, 0, 3, 0, 8, 1, 3, 5, 3, 3, 6, 2, 7, 6, 6, 1, 4, 2, 8, 2, 8, 0, 6, 4, 4, 4, 4, 8, 6, 6, 4, 5, 2, 3, 8, 7, 4, 9, 3, 0, 3, 5, 8, 9, 0, 7, 2, 9, 6, 2, 9, 0, 4, 9, 1, 5, 6, 0, 4, 4, 0, 7, 7, 2, 3, 9, 0, 7, 1, 3, 8
# ...

# %% [markdown]
# 1000자리의 수를 리스트에 각각 int로 변환시켜 저장시키고, 5개씩 끊어서 곱셈을 한후 비교를 위해 범위를 리스트의 길이보다 -4였다. 그후 5자리 숫자의 곱을 반복적으로 구하고 비교시켜 가장 큰 값이 남도록 하였다.

# %% [markdown]
# 10)[프로젝트 오일러 문제 9]

# %%
import math

def pytha(n):
    for i in range(1,n):
        for j in range(1,n-i):
            k = math.sqrt(i**2 + j**2)
            if i+j+k ==1000:
                return int(i*j*k)
print pytha(1000)
# Out:
# 31875000

# %% [markdown]
# i,j가 1이상의 정수 범위에서 반복되므로, 세 수의 합이 1000이 나오려면 k는 자동적으로 자연수 범위에서 나오게된다. i,j의 제곱의 합을 다시 제곱근을 구하는 방식으로 답을 도출했다.

# %% [markdown]
# 11)[Incremental Project] 이전 Assignment 2의 마지막 문제는 웹 URL로 지정된 웹페이지를 문자열로 가져와 모든 HTML 태그 및 CSS와 Javascript를 제외한 순수 텍스트를 얻어내고 그 안에 존재하는 단어를 추출하고 단어들의 총 개수를 출력하는 프로그램을 작성하는 것이었다. 이번에는 그 마지막 숙제를 그대로 확장하여 웹 URL로 지정된 웹페이지 내 순수 텍스트 안에 존재하는 각 단어들에 대해 다음 요구사항 대로 출력하는 프로그램을 작성하시오.
#
# ◾요구사항 1. 순수 텍스트 안에 존재하는 단어들에 대해 string 모듈을 활용하여 모든 punctuation (구두문자)를 완벽히 제거하시오.◦예: ['world!', ':', '+hello+', '~python$$$', '=', 'world'] ---> ['world', 'hello', 'python', 'world']
# ◦모든 punctuation을 확인하는 방법은 아래와 같다.import string
# print string.punctuation
#
# ◾요구사항 2. 만약 punctuation (구두문자)를 제거한 이후 공백으로 판명되는 단어들은 해당 단어 리스트에서 제거하시오.◦예: ['컴퓨터공학부!', '---?', '%지향~', '...'] ---> ['컴퓨터공학부', '지향']
#
# ◾요구사항 3. 각 단어들의 출현빈도를 사전형태로 저장하여 출력하시오.◦예: ['world', 'hello', 'python', 'world', '컴퓨터공학부', '지향'] ---> {'world': 2, 'hello': 1, 'python': 1, '컴퓨터공학부': 1, '지향': 1}
#
# ◾요구사항 4. 다음 3개의 사이트에 대한 결과를 출력하시오.
# ◦http://www.naver.com
# ◦http://www.daum.net
# ◦http://www.nytimes.com

# %%
import urllib2
import string

source = urllib2.urlopen("http://www.naver.com").read()

#print source # 추후 숙제 답안 제출 때엔 왼쪽 라인은 주석처리할 것
L = []

index = 1 #리스트에 넣을지 안넣을지 구분.
temp = ""

for ch in source:
    if ch == '<':
        index = 1
        if len(temp.strip()) > 0:
            word_temp = temp.split() #공백단위로 분리
            if len(word_temp) > 0:
                for a in word_temp:
                    a = a.translate(string.maketrans("",""), string.punctuation)
                    if a != '' :
                        L.append(a)

        temp = ""
    
    if ch == '>':
        index = 0
        continue
    
    if index is 0:
        temp += ch

        
        
cnt = 0
freq = []
for ch in L: #원소 읽기
    print '"'+ch+'"',
    cnt += 1
    freq.append(L.count(ch))
print
print dict(zip(L, freq))
print "\n단어 수 : " + str(cnt)
# Out:
# "NAVER" "var" "isLogin" "false" "var" "global" "isSupportedFlicking" "false" "isIPAD" "false" "var" "strHost" "wwwnavercom" "var" "isMobile" "false" "var" "isMyCast" "false" "var" "svr" "var" "LogErrorfunctionbvar" "anew" "Imageasrchttpcecsnavercommbudocumentlocationl1115DLScriptquSXInew" "ArrayquSnew" "Arrayretry0isLoadfunctionaforvar" "bthisquSlength1" "b0bifthisquSbareturn" "truereturn" "falserunOnloadfunctionbdcifdreturnvar" "abreadyStateiftypeof" "aundefinedbonloadDonebonloadDonetruecsetTimeoutd100bonloadd" "returnifloadedacompleteabonloadDonebonloadDonetruesetTimeoutd100elseifthisretry" "0iikopenGETcltrueksetRequestHeaderContentTypeapplicationxwwwformurlencoded" "charsetutf8ksetRequestHeadercharsetutf8ksend" "elseifgsetTimeoutg100injectScriptsfunctionvar" "aDLScriptquSXIlengthforvar" "c0c" "clearLSfunctioniftypeof" "windowlocalStorageundefinedtrywindowlocalStorageclearcatchaifadescriptionLogErrorDL" "clearLS" "adescriptionremoveUrlfunctionaforvar" "bthisquSlength1" "b0bifthisqu
# ...

# %%
import urllib2
import string

source = urllib2.urlopen("http://daum.net").read()

#print source # 추후 숙제 답안 제출 때엔 왼쪽 라인은 주석처리할 것
L = []

index = 1 #리스트에 넣을지 안넣을지 구분.
temp = ""

for ch in source:
    if ch == '<':
        index = 1
        if len(temp.strip()) > 0:
            word_temp = temp.split() #공백단위로 분리
            if len(word_temp) > 0:
                for a in word_temp:
                    a = a.translate(string.maketrans("",""), string.punctuation)
                    if a != '' :
                        L.append(a)

        temp = ""
    
    if ch == '>':
        index = 0
        continue
    
    if index is 0:
        temp += ch

        
        
cnt = 0
freq = []
for ch in L: #원소 읽기
    print '"'+ch+'"',
    cnt += 1
    freq.append(L.count(ch))
print
print dict(zip(L, freq))
print "\n단어 수 : " + str(cnt)
# Out:
# "Daum" "ndash" "모으다" "잇다" "흔들다" "bodydivdldtddulollih1h2h3h4h5h6precodeformfieldsetlegendtextareapblockquotethtdinputselecttextareabutton" "margin0padding0" "fieldsetimg" "border0" "none" "dlulolmenuli" "liststylenone" "blockquote" "q" "quotes" "none" "blockquotebefore" "blockquoteafterqbefore" "qafter" "contentcontentnone" "inputselecttextareabutton" "verticalalignmiddle" "inputmsclear" "displaynone" "button" "border0" "nonebackgroundcolortransparentcursorpointer" "body" "backgroundfff" "urlhttpi1daumcdnnetdecocomicstopdeco2014v2bgtopbargifv1102" "repeatx" "0" "0directionltr" "bodyh1h2h3h4thtdinputselecttextareabutton" "fontsize12pxlineheight15fontfamily돋움dotumsansserifcolor333" "a" "color262626textdecorationnone" "ahover" "color4559e9textdecorationunderline" "aactive" "backgroundcolortransparent" "addresscaptioncitecodedfnemvar" "fontstylenormalfontweightnormal" "headermainasidearticlefooter" "displayblock" "wrapdaum" "width940pxmargin0" "auto" "headdaum" "positionrelativewidth940p
# ...

# %%
source = urllib2.urlopen("http://www.nytimes.com").read()

#print source # 추후 숙제 답안 제출 때엔 왼쪽 라인은 주석처리할 것
L = []

index = 1 #리스트에 넣을지 안넣을지 구분.
temp = ""

for ch in source:
    if ch == '<':
        index = 1
        if len(temp.strip()) > 0:
            word_temp = temp.split() #공백단위로 분리
            if len(word_temp) > 0:
                for a in word_temp:
                    a = a.translate(string.maketrans("",""), string.punctuation)
                    if a != '' :
                        L.append(a)

        temp = ""
    
    if ch == '>':
        index = 0
        continue
    
    if index is 0:
        temp += ch

        
        
cnt = 0
freq = []
for ch in L: #원소 읽기
    print '"'+ch+'"',
    cnt += 1
    freq.append(L.count(ch))
print
print dict(zip(L, freq))
print "\n단어 수 : " + str(cnt)
# Out:
# "The" "New" "York" "Times" "Breaking" "News" "World" "News" "Multimedia" "windowNREUMNREUMnrrequirefunctionentfunction" "rtifntvar" "ontexportset0calloexportsfunctionnvar" "oet1nreturn" "roonooexportsreturn" "ntexportsiffunctiontypeof" "nrrequirereturn" "nrrequireforvar" "o0o" "ppupapplystreturn" "sfunction" "aenfececoncatnfunction" "cereturn" "fefunction" "ureturn" "tnvar" "freturnonaemitncreateulistenersceventsffunction" "rreturnvar" "onrcontextiegosnexportstgos7eSDFheefunctionennexportseQJf3ax3functionenfunction" "tereturn" "functionrenew" "DategetTimeconcatiargumentsvar" "rehandleoe1ie2undefinedtypeof" "windownewrelicnewrelicwindowNREUMvar" "asetPageViewNameaddPageActionsetCustomAttributefinishedaddToTraceinlineHitnoticeErroroafunctionenwindowNREUMntapinnexportswindowNREUM112213handleD5DuLPgosfunctionennexportse7eSDFh7eSDFhfunctionenfunction" "tentifrcallenreturn" "envar" "otifObjectdefinePropertyObjectkeystryreturn" "ObjectdefinePropertyenvalueowritable0enumerable1ocatchireturn"
# ...

# %% [markdown]
# maketrans()와 translate()을 사용하였다. maketrans는 인자가 둘인 경우 길이가 같은 문자열을 받아 사용. 빈도는 count()함수를 사용해서 문장내의 단어를 세었는데, 한글의 경우 사전으로 출력했을때, 정상적인 단어로 나오지 않았다.

# %% [markdown]
# 난이도가 제 수준에 비해 많이 높아져서 과제하는것에 많은 시간이 걸렸습니다. 당연하게 사용하는 슬라이싱같은경우도 왜 그런가 설명할 수 있기위해 정확한 이해가 필요한 부분이었습니다.
